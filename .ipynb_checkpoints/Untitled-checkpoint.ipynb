# %% [markdown]
# # Top 5 Zip Codes in Florida to Invest In
# **Author:** Aziza Gulyamova
# ***

# %% [markdown]
# ## Overview

# %% [markdown]
# For this project, I will be acting as a consultant for a real-estate investment firm. The main goal for my project is to identify **Top 5 zip codes** that are worth investing in anfd **forecast the price**. The assumptions of the best Zip code are following:

# %% [markdown]
# * The minimum capital for entering the market is \$200,000
# * Highly urbanized U.S. areas
# * Low risk factor (low volatility threshold)
#
# ***

# %% [markdown]
# ### Why Florida State?

# %% [markdown]
# Florida real estate has always been a good deal for investors. Stunning beaches, beautiful weather, numerous landmarks and attractions, various opportunities and no income tax are just a few of the top reasons why new residents and investors are attracted to Florida. In 2019 Florida became one of the seven states that forgo individual income taxes. In addition, mortgage rates are still at the lowest levels since the 1960s. The housing market is more stable compared to the early 2010s.
#
# Source: Florida Property Management & Sales
# Link to article: https://floridapropertyrealty.com/tax-benefits-florida-real-estate/
# ***

# %% [markdown]
# ## Data

# %% [markdown]
# The **Home Listing and Sales** dataset was provided by **Zillow Research**. The data represents **median monthly housing sales prices** over the period of April 1996 through April 2018.
#
# Each row represents a unique zip code. Each record contains location info and median housing sales prices for each month.
#
# The raw CSV contained the following **columns:**
#
# RegionID
# RegionName -- ZIP Code
# City
# State
# Metro
# CountyName
# SizeRank -- rank of the zipcode according to urbanization.
#
# **Link to dataset:** https://www.zillow.com/research/data/

# %% [markdown]
# ## Plan of Analysis
#
# <br>
# <details><summary><b>Data Exploration</b></summary>
#     <ul>
#         <li>Import Packages</li>
#         <li>Upload Dataset</li>
#         <li>Explore Dataset</li>
#         <li>Visual Exploration</li>
#     </ul>
# </details>
# <details><summary><b>Exploration Analysis</b></summary>
#     <ul>
#         <li>Minimum Price</li>
#         <li>Volatility</li>
#         <li>ROI for 24 Months</li>
#     </ul>
# </details>
# <details><summary><b>Data Preparation</b></summary>
#     <ul>
#         <li>Sationarity</li>
#         <li>Non Stationary to Stationary</li>
#         <li>ACF and PACF</li>
#     </ul>
# </details>
#
# <details><summary><b>BASELINE AUTO-ARIMA MODEL</b></summary>
#     <ul>
#         <li><b>Train Test Split</b></li>
#         <li>## 33064 Zipcode Model</li>
#         <li>## 33157 Zipcode Model</li>
#         <li>## 32825 Zipcode Model</li>
#         <li>## 33463 Zipcode Model</li>
#         <li>## 34698 Zipcode Model</li>
#         <li>## 33020 Zipcode Model</li>
#         <li>## 33033 Zipcode Model</li>
#         <li>## 32771 Zipcode Model</li>
#     </ul>
# </details>
# <b>SARIMAX (2, 0, 0) Model</b>
# <details><summary><b>Facebook Prophet Model</b></summary>
#     <ul>
#         <li>Train - Test Split</li>
#         <li>## 33064 Zipcode</li>
#         <li>## 33033 Zipcode</li>
#         <li>## 33157 Zipcode</li>
#     </ul>
# </details>
# <b>Final SARIMAX (2, 0, 0) Model</b>
# <details><summary><b>Results and Conclusions</b></summary>
#     <ul>
#         <li>Results</li>
#         <li>Notes</li>
#         <li>Next Steps</li>
#     </ul>
# </details>

# %% [markdown]
# # Data Exploration
# Before proceeding to any analysis and modeling, I will need to upload necessary packages and upload dataset. After that, the data needs to bee explored and cleaned from unnecessary columns and observations.

# %% [markdown]
# ## Import Packages

# %% [markdown]
# Import necessary packages and libraries for data cleaning and manipulation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from functools import reduce
from datetime import datetime

from sklearn.metrics import mean_squared_error



from statsmodels.tsa.arima.model import ARIMA, ARIMAResults
#from statsmodels.tsa.arima_model import ARMA,ARMAResults,ARIMA,ARIMAResults
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf # for determining (p,q) orders
from statsmodels.tsa.stattools import adfuller #perform dickey-fuller test

from statsmodels.tsa.statespace.sarimax import SARIMAX  #seasonal ARIMA
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf # for determining (p,q) orders
from statsmodels.tsa.seasonal import seasonal_decompose      # for ETS Plots

from pmdarima import auto_arima                              # for determining ARIMA orders

from fbprophet import Prophet

# Ignore harmless warnings
import warnings
warnings.filterwarnings("ignore")

import itertools


# Import additional files with statistical functions
import sys
import os

module_path = os.path.abspath(os.path.join('./src'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import explore_data as ed
import ts_functions as tsf

# %% [markdown]
# Import and load modeling and forecasting tools

# %% [markdown]
# Adjust the notebook settings

# %%
pd.options.display.max_rows = 700
pd.options.display.max_columns = 100
plt.style.use('seaborn')

# %% [markdown]
# ## Upload Dataset

# %% [markdown]
# The dataset is provided by **Zillow Resarch** and stored in **Dataset folder** of the project. I will upload data into **zillow** variable and store all features as an object data type in order to keep possible leading zeros.

# %%
zillow = pd.read_csv('./data/zillow_data.csv', dtype = 'object' )

# %%
zillow.head()
# Out:
#   RegionID RegionName      City State              Metro CountyName SizeRank  \
# 0    84654      60657   Chicago    IL            Chicago       Cook        1
# 1    90668      75070  McKinney    TX  Dallas-Fort Worth     Collin        2
# 2    91982      77494      Katy    TX            Houston     Harris        3
# 3    84616      60614   Chicago    IL            Chicago       Cook        4
# 4    93144      79936   El Paso    TX            El Paso    El Paso        5
#
#   1996-04 1996-05 1996-06 1996-07 1996-08 1996-09 1996-10 1996-11 1996-12  \
# 0  334200  335400  336500  337600  338500  339500  340400  341300  342600
# 1  235700  236900  236700  235400  233300  230600  227300  223400  219600
# 2  210400  212200  212200  210700  208300  205500  202500  199800  198300
# 3  498100  500900  503100  504600  505500  505700  505300  504200  503600
# 4   77300   77300   77300   77300   77400   77500   77600   77700   77700
#
#   1997-01 1997-02 1997-03 1997-04 1997-05 1997-06 1997-07 1997-08 1997-09  \
# 0  344400  345700  346700  347800  349000  350400  352000  353900  356200
# 1  215800  211100  205700  200900  196800  193600  191400  190400  190800
# 2  197300  195400  193000  191800  191800  193000  195200  198400  202800
# 3  503400  502200  500000  497900  496300  495200  494700  494900  496200
# 4   77800   77900   77900   77800   77800   77800   77800   77800   77900
#
#   1997-10 1997-11 1997-12 1998-01 1998-02 1998-03 1998-04 1998-05 1998-06  \
# 0  358800  361800  365700  370200  374700  378900  383500  388300  393300
# 1  192700  196000  201300  207400  212200  214600  215100  213400  210200
# 2  208000  213800  220700  227500  231800  233400  233900  233500  233300
# 3  498600  502000  507600  514900  522200  529500  537900  546900  556400
# 4   78100   78200   78400   78600   78800   79000   79100   79200   79300
#
#   1998-07 1998-08 1998-09 1998-10 1998-11 1998-12 1999-01 1999-02 1999-03  \
# 0  398500  403800  409100  414600  420100  426200  432600  438600  444200
# %%
zillow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14723 entries, 0 to 14722
# Columns: 272 entries, RegionID to 2018-04
# dtypes: object(272)
# memory usage: 30.6+ MB

# %% [markdown]
# * The data appears to be stored in **wide format**, meaning that the **observations of time feature are stored as individual columns** with median **house price value as observations**.

# %% [markdown]
# ## Explore Data

# %% [markdown]
# * Extract data for **Florida State**
# * Choose **highly urbanized** zipcodes
# * Remove **unnecessary variables**
# * Check for missing values

# %% [markdown]
# For my project, I chose to focus on **zipcodes of the FL state**, since it is one of the states with **high inbound migration** percentage and also has **no state income taxation**. Thus, the real estate market there is at **high performance.**

# %% [markdown]
# First, I will select observations only for FL state.

# %%
fl_df = zillow[zillow['State']=='FL']
fl_df.head()
# Out:
#    RegionID RegionName               City State                  Metro  \
# 11    71831      32162       The Villages    FL           The Villages
# 60    72463      33160  Sunny Isles Beach    FL  Miami-Fort Lauderdale
# 82    72363      33025            Miramar    FL  Miami-Fort Lauderdale
# 83    72578      33411   Royal Palm Beach    FL  Miami-Fort Lauderdale
# 84    72442      33139        Miami Beach    FL  Miami-Fort Lauderdale
#
#     CountyName SizeRank 1996-04 1996-05 1996-06 1996-07 1996-08 1996-09  \
# 11      Sumter       12  101000  100700  100400  100100   99800   99500
# 60  Miami-Dade       61  337300  337900  338300  338400  338400  338200
# 82     Broward       83  111600  111700  111800  111900  112000  112100
# 83  Palm Beach       84  126800  126800  126800  126800  126700  126700
# 84  Miami-Dade       85  480200  480700  481200  481600  482000  482500
#
#    1996-10 1996-11 1996-12 1997-01 1997-02 1997-03 1997-04 1997-05 1997-06  \
# 11   99200   98900   98600   98000   97100   95800   94300   92800   91500
# 60  338000  338000  338400  339100  339400  339000  338500  337900  337000
# 82  112200  112300  112500  112700  112800  112700  112600  112500  112300
# 83  126800  126800  127000  127100  127200  127100  127000  127100  127200
# 84  483100  483700  484800  486100  486900  486900  486600  486300  485800
#
#    1997-07 1997-08 1997-09 1997-10 1997-11 1997-12 1998-01 1998-02 1998-03  \
# 11   90500   89800   89500   89300   89400   89800   90500   91500   92700
# 60  335900  334800  333800  333000  332400  332600  333300  333800  333900
# 82  112200  112100  112100  112200  112400  112800  113400  114000  114300
# 83  127600  128000  128600  129300  130100  131100  132000  132900  133400
# 84  485100  484300  483500  482700  482000  481900  482100  482000  481400
#
#    1998-04 1998-05 1998-06 1998-07 1998-08 1998-09 1998-10 1998-11 1998-12  \
# 11   94100   95700   97200   98400   99400  100300  101200  102400  104000
# 60  334000  334100  334200  334300  334500  334900  335600  336600  338500
# 82  114600  114900  115000  115100  115100  115200  115200  115300  115500
# 83  133800  134100  134300  134500  134500  134500  134600  134600  134700
# 84  481000  480900  481000  481500  482400  483800  485600  487900  491200
#
#    1999-01 1999-02 1999-03 1999-04 1999-05 1999-06 1999-07 1999-08 1999-09  \
# 11  106000  108300  110700  113200  115700  117900  119700  121200  122400
# 60  341000  343400  345500  347800  350200  352600  355100  357700  360600
# 82  115900  116200  116400  116600  116800  116900  117000  117100  117300
# 83  134800  135000  135100  135400  135800  136200  136700  137300  138000
# 84  495100  498900  502600  506800  511400  516300  521600  527300  533500
#
#    1999-10  ...  2014-03  2014-04  2014-05  2014-06  2014-07  2014-08  \
# 11  123400  ...   228200   229800   231600   233600   235700   237900
# 60  363800  ...  1016000  1023400  1032400  1043400  1072200  1115700
# 82  117500  ...   185600   186100   187100   188800   191100   193800
# 83  138700  ...   216800   219400   222500   226600   230600   233100
# 84  540100  ...  1954400  1970500  1993600  2018700  2045300  2074500
#
#     2014-09  2014-10  2014-11  2014-12  2015-01  2015-02  2015-03  2015-04
014-06  2014-07  2014-08  2014-09  2014-10  2014-11  2014-12  2015-01  \
# 0   233600   235700   237900   239500   240400   240900   241300   241800
# 1  1043400  1072200  1115700  1147800  1151900  1150200  1141400  1134200
# 2   188800   191100   193800   195800   197500   199600   201900   204100
# 3   226600   230600   233100   234300   235800   237500   239100   240400
# 4  2018700  2045300  2074500  2122900  2187500  2228000  2240400  2251600
#
#    2015-02  2015-03  2015-04  2015-05  2015-06  2015-07  2015-08  2015-09  \
# 0   242600   243400   244100   244400   244200   243900   244800   247600
# 1  1152000  1197200  1236200  1264200  1290500  1304300  1308200  1317500
# 2   206600   209700   213200   216400   219300   222200   224800   226700
# 3   242200   245000   247600   249300   250600   251900   253300   255400
# 4  2265500  2292100  2342700  2391200  2427000  2436500  2467500  2526100
#
#    2015-10  2015-11  2015-12  2016-01  2016-02  2016-03  2016-04  2016-05  \
# 0   250100   251000   251600   252000   252000   251400   250700   250200
# 1  1335100  1350100  1358200  1365200  1377400  1389700  1393600  1388400
# 2   228200   230200   232300   234600   236300   237400   238300   240600
# 3   257900   260400   263600   266800   268600   269600   271100   273200
# 4  2566900  2570100  2590900  2627200  2656400  2668800  2704600  2726200
#
#    2016-06  2016-07  2016-08  2016-09  2016-10  2016-11  2016-12  2017-01  \
# 0   249200   247900   246800   246400   246200   246600   246500   246600
# 1  1386800  1393400  1394800  1390500  1401200  1419300  1431100  1441200
# 2   244000   247500   250600   254200   258000   261500   265200   269200
# 3   275100   276800   278800   280900   282900   284600   286400   288300
# 4  2721300  2715800  2737800  2741200  2770600  2819400  2841100  2832700
#
#    2017-02  2017-03  2017-04  2017-05  2017-06  2017-07  2017-08  2017-09  \
# 0   247200   248100   248400   248700   249300   249900   250400   249900
# 1  1447700  1449600  1465500  1479400  1474400  1466200  1471000  1485400
# 2   272500   275200   277900   279900   281300   283500   286100   287800
# 3   290100   291600   292800   294100   295700   297400   299300   301400
# 4  2849300  2884900  2899400  2904700  2907900  2917100  2925700  2942400
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0   248700   247500   247100   246800   247500   249800   251800
# 1  1497700  1504200  1507600  1495800  1466200  1443900  1432300
# 2   288800   289700   291000   292500   294200   296400   298200
# 3   303300   304900   307100   309800   311700   312600   313100
# 4  2958300  2946300  2912900  2900900  2923300  2933600  2914100
#
# [5 rows x 267 columns]

# %% [markdown]
# ### Highly Urbanized Zip Codes

# %% [markdown]
# I will sort out the zipcodes with highest **SizeRank**, since the real estate market is higly growing where the urbanization is high. I will keep zip codes that are at **top 15 quantile** according to the SizeRank variable.

# %%
#first, convert SizeRank variable to numeric data type
fl_df["SizeRank"]=fl_df["SizeRank"].astype(int)

#calculate the 0.15 quantile
sr_15q = fl_df.SizeRank.quantile(q=0.15) 
# select data only in top 15 quantile of SizeRank
fl_top15= fl_df[fl_df['SizeRank']<sr_15q]

# %%
fl_top15.drop(columns = 'SizeRank', inplace = True, axis = 1)
fl_top15.head()
# Out:
#   Zipcode 1996-04 1996-05 1996-06 1996-07 1996-08 1996-09 1996-10 1996-11  \
# 0   32162  101000  100700  100400  100100   99800   99500   99200   98900
# 1   33160  337300  337900  338300  338400  338400  338200  338000  338000
# 2   33025  111600  111700  111800  111900  112000  112100  112200  112300
# 3   33411  126800  126800  126800  126800  126700  126700  126800  126800
# 4   33139  480200  480700  481200  481600  482000  482500  483100  483700
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.5), ncol= 10, fontsize = 'x-large')
plt.gcf().autofmt_xdate()

# %% [markdown]
# * It is clear that most of the zipcodes has low volatility, but there are some that have noticable trendiness. The downfall in period from 2007 - 2012 had occured due to economic crash in Great Recession period. According to IG.Ellen, one of the truly distinctive features of Great Recession is the severe housing crisis layered on top of all the labor market problems (G.Ellen, 2012).
# After 2012 the market started to recover.

# %% [markdown]
# ### Select after 2012

# %% [markdown]
# Since the fluctuation above can **significantly impact the models' performance and accuracy**, I will select **observations only after 2012.**

# %%
fl_df=fl_df.transpose()
fl_df.head()
# Out:
#          1996-04-01  1996-05-01  1996-06-01  1996-07-01  1996-08-01  \
# Zipcode
# 32162        101000      100700      100400      100100       99800
# 33160        337300      337900      338300      338400      338400
# 33025        111600      111700      111800      111900      112000
# 33411        126800      126800      126800      126800      126700
# 33139        480200      480700      481200      481600      482000
#
#          1996-09-01  1996-10-01  1996-11-01  1996-12-01  1997-01-01  \
# Zipcode
# 32162         99500       99200       98900       98600       98000
# 33160        338200      338000      338000      338400      339100
# 33025        112100      112200      112300      112500      112700
# 33411        126700      126800      126800      127000      127100
# 33139        482500      483100      483700      484800      486100
#
#          1997-02-01  1997-03-01  1997-04-01  1997-05-01  1997-06-01  \
# Zipcode
# 32162         97100       95800       94300       92800       91500
# 33160        339400      339000      338500      337900      337000
# 33025        112800      112700      112600      112500      112300
# 33411        127200      127100      127000      127100      127200
# 33139        486900      486900      486600      486300      485800
#
#          1997-07-01  1997-08-01  1997-09-01  1997-10-01  1997-11-01  \
# Zipcode
# 32162         90500       89800       89500       89300       89400
# 33160        335900      334800      333800      333000      332400
# 33025        112200      112100      112100      112200      112400
# 33411        127600      128000      128600      129300      130100
# 33139        485100      484300      483500      482700      482000
#
#          1997-12-01  1998-01-01  1998-02-01  1998-03-01  1998-04-01  \
# Zipcode
# 32162         89800       90500       91500       92700       94100
# 33160        332600      333300      333800      333900      334000
# 33025        112800      113400      114000      114300      114600
# 33411        131100      132000      132900      133400      133800
# 33139        481900      482100      482000      481400      481000
#
#          1998-05-01  1998-06-01  1998-07-01  1998-08-01  1998-09-01  \
# Zipcode
# 32162         95700       97200       98400       99400      100300
# 33160        334100      334200      334300      334500      334900
# 33025        114900      115000      115100      115100      115200
# 33411        134100      134300      134500      134500      134500
# 33139        480900      481000      481500      482400      483800
#
#          1998-10-01  1998-11-01  1998-12-01  1999-01-01  1999-02-01  \
# Zipcode
# 32162        101200      102400      104000      106000      108300
# 33160        335600      336600      338500      341000      343400
# 33025        115200      115300      115500      115900      116200
# 33411        134600      134600      134700      134800      135000
# 33139        485600      487900      491200      495100      498900
#
#          1999-03-01  1999-04-01  1999-05-01  1999-06-01  1999-07-01  \
# Zipcode
# 32162        110700      113200      115700      117900      119700
# 33160        345500      347800      350200      352600      355100
# 33025        116400      116600      116800      116900      117000
# 33411        135100      135400      135800      136200      136700
# 33139        502600      506800      511400      516300      521600
#
# 33411        290100      291600      292800      294100      295700
# 33139       2849300     2884900     2899400     2904700     2907900
#
#          2017-07-01  2017-08-01  2017-09-01  2017-10-01  2017-11-01  \
# Zipcode
# 32162        249900      250400      249900      248700      247500
# 33160       1466200     1471000     1485400     1497700     1504200
# 33025        283500      286100      287800      288800      289700
# 33411        297400      299300      301400      303300      304900
# 33139       2917100     2925700     2942400     2958300     2946300
#
#          2017-12-01  2018-01-01  2018-02-01  2018-03-01  2018-04-01
# Zipcode
# 32162        247100      246800      247500      249800      251800
# 33160       1507600     1495800     1466200     1443900     1432300
# 33025        291000      292500      294200      296400      298200
# 33411        307100      309800      311700      312600      313100
# 33139       2912900     2900900     2923300     2933600     2914100
#
# [5 rows x 265 columns]

# %%
fl_df.columns.get_loc('2012-01-01')
# Out:
# 189

# %%
fl_df.drop(fl_df.columns[:189], axis=1,inplace=True)
fl_df.head()
# Out:
#          2012-01-01  2012-02-01  2012-03-01  2012-04-01  2012-05-01  \
# Zipcode
# 32162        194300      194500      195300      196500      197900
# 33160        857200      859700      861700      862900      866900
# 33025        161300      160600      159600      159400      160400
# 33411        168300      168000      167900      168000      168600
# 33139       1443900     1460300     1478600     1506500     1540000
#
#          2012-06-01  2012-07-01  2012-08-01  2012-09-01  2012-10-01  \
# Zipcode
# 32162        199100      200000      200700      201600      202500
# 33160        867400      860500      851300      848200      846200
# 33025        161200      161200      160300      160000      160000
# 33411        168900      168500      168100      168200      168400
# 33139       1561600     1577100     1595200     1612700     1625300
#
#          2012-11-01  2012-12-01  2013-01-01  2013-02-01  2013-03-01  \
# Zipcode
# 32162        203600      204500      205100      205500      205900
# 33160        848200      855800      866400      876200      886900
# 33025        160200      160400      160700      161400      163800
# 33411        169400      171200      173200      175600      178200
# 33139       1649900     1684400     1719900     1735000     1737900
#
#          2013-04-01  2013-05-01  2013-06-01  2013-07-01  2013-08-01  \
# Zipcode
# 32162        206600      207800      209600      211500      213400
# 33160        896700      907000      919100      928500      937600
# 33025        167500      170300      172100      173800      176700
# 33411        181200      184700      188500      192400      196900
# 33139       1739200     1764100     1805200     1843700     1869900
#
#          2013-09-01  2013-10-01  2013-11-01  2013-12-01  2014-01-01  \
# Zipcode
# 32162        215200      217600      220300      223100      225400
# 33160        952300      963000      963200      973900      994100
# 33025        179100      180300      181700      183200      183900
# 33411        200900      204300      207200      209500      211600
# 33139       1889500     1891800     1885700     1896600     1923400
#
#          2014-02-01  2014-03-01  2014-04-01  2014-05-01  2014-06-01  \
# Zipcode
# 32162        227000      228200      229800      231600      233600
# 33160       1009400     1016000     1023400     1032400     1043400
# 33025        184800      185600      186100      187100      188800
# 33411        214100      216800      219400      222500      226600
# 33139       1946400     1954400     1970500     1993600     2018700
#
#          2014-07-01  2014-08-01  2014-09-01  2014-10-01  2014-11-01  \
# Zipcode
# 32162        235700      237900      239500      240400      240900
# 33160       1072200     1115700     1147800     1151900     1150200
# 33025        191100      193800      195800      197500      199600
# 33411        230600      233100      234300      235800      237500
# 33139       2045300     2074500     2122900     2187500     2228000
#
#  62  2017-03-01 00:00:00  118 non-null    int64
#  63  2017-04-01 00:00:00  118 non-null    int64
#  64  2017-05-01 00:00:00  118 non-null    int64
#  65  2017-06-01 00:00:00  118 non-null    int64
#  66  2017-07-01 00:00:00  118 non-null    int64
#  67  2017-08-01 00:00:00  118 non-null    int64
#  68  2017-09-01 00:00:00  118 non-null    int64
#  69  2017-10-01 00:00:00  118 non-null    int64
#  70  2017-11-01 00:00:00  118 non-null    int64
#  71  2017-12-01 00:00:00  118 non-null    int64
#  72  2018-01-01 00:00:00  118 non-null    int64
#  73  2018-02-01 00:00:00  118 non-null    int64
#  74  2018-03-01 00:00:00  118 non-null    int64
#  75  2018-04-01 00:00:00  118 non-null    int64
# dtypes: int64(76)
# memory usage: 76.0+ KB

# %%
avg_price = (fl_df['2018-01-01'] + fl_df['2018-02-01'] + 
             fl_df['2018-03-01'] + fl_df['2018-04-01']) / 4
avg_price.head()
# Out:
# Zipcode
# 32162     248975.0
# 33160    1459550.0
# 33025     295325.0
# 33411     311800.0
# 33139    2917975.0
# dtype: float64

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Median House Price for Zipcodes in 2018')
ax1.boxplot(avg_price)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc6817a1550>,
#   <matplotlib.lines.Line2D at 0x7fc6817a1940>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc6d50adcf8>,
#   <matplotlib.lines.Line2D at 0x7fc6d50ad080>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc6817a1278>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc6d50ad2e8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc6d50ad518>],
#  'means': []}

# %% [markdown]
# * The boxplot shows that at some zipcodes **the median price for the house is extremly high**. I will drop those zipcodes from the dataset, since they **represent outliers.**

# %%
zipcodes = avg_price.index[avg_price > 500000].to_list()
zipcodes
# Out:
# ['33160', '33139', '33141', '33308', '33062', '33180']

# %%
fl_df.drop(zipcodes, inplace=True)
fl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 112 entries, 32162 to 34786
# Data columns (total 76 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   2012-01-01 00:00:00  112 non-null    int64
#  1   2012-02-01 00:00:00  112 non-null    int64
#  2   2012-03-01 00:00:00  112 non-null    int64
#  3   2012-04-01 00:00:00  112 non-null    int64
#  4   2012-05-01 00:00:00  112 non-null    int64
#  5   2012-06-01 00:00:00  112 non-null    int64
#  6   2012-07-01 00:00:00  112 non-null    int64
#  7   2012-08-01 00:00:00  112 non-null    int64
#  8   2012-09-01 00:00:00  112 non-null    int64
#  9   2012-10-01 00:00:00  112 non-null    int64
#  10  2012-11-01 00:00:00  112 non-null    int64
#  11  2012-12-01 00:00:00  112 non-null    int64
#  12  2013-01-01 00:00:00  112 non-null    int64
#  13  2013-02-01 00:00:00  112 non-null    int64
#  14  2013-03-01 00:00:00  112 non-null    int64
#  15  2013-04-01 00:00:00  112 non-null    int64
#  16  2013-05-01 00:00:00  112 non-null    int64
#  17  2013-06-01 00:00:00  112 non-null    int64
#  18  2013-07-01 00:00:00  112 non-null    int64
#  19  2013-08-01 00:00:00  112 non-null    int64
#  20  2013-09-01 00:00:00  112 non-null    int64
#  21  2013-10-01 00:00:00  112 non-null    int64
#  22  2013-11-01 00:00:00  112 non-null    int64
#  23  2013-12-01 00:00:00  112 non-null    int64
#  24  2014-01-01 00:00:00  112 non-null    int64
#          2014-07-01  2014-08-01  2014-09-01  2014-10-01  2014-11-01  \
# Zipcode
# 32162        235700      237900      239500      240400      240900
# 33025        191100      193800      195800      197500      199600
# 32210         64900       65400       66600       67700       68500
# 33024        170300      172000      173200      173800      174400
# 33009        141400      143600      144400      144600      145100
#
#          2014-12-01  2015-01-01  2015-02-01  2015-03-01  2015-04-01  \
# Zipcode
# 32162        241300      241800      242600      243400      244100
# 33025        201900      204100      206600      209700      213200
# 32210         68700       68600       68400       68400       69000
# 33024        175700      177800      180700      182900      184500
# 33009        145800      146600      147600      148700      149800
#
#          2015-05-01  2015-06-01  2015-07-01  2015-08-01  2015-09-01  \
# Zipcode
# 32162        244400      244200      243900      244800      247600
# 33025        216400      219300      222200      224800      226700
# 32210         70500       72600       74600       76500       78200
# 33024        186500      188600      190600      193200      196000
# 33009        151100      151800      152200      153600      155900
#
#          2015-10-01  2015-11-01  2015-12-01  2016-01-01  2016-02-01  \
# Zipcode
# 32162        250100      251000      251600      252000      252000
# 33025        228200      230200      232300      234600      236300
# 32210         80000       81400       82300       83100       84400
# 33024        198400      200700      203000      205400      207300
# 33009        158200      160900      163300      164800      166100
#
#          2016-03-01  2016-04-01  2016-05-01  2016-06-01  2016-07-01  \
# Zipcode
# 32162        251400      250700      250200      249200      247900
# 33025        237400      238300      240600      244000      247500
# 32210         86700       89800       92400       94600       97100
# 33024        209100      211700      215800      220000      223500
# 33009        168200      170000      171900      174700      177700
#
#          2016-08-01  2016-09-01  2016-10-01  2016-11-01  2016-12-01  \
# Zipcode
# 32162        246800      246400      246200      246600      246500
# 33025        250600      254200      258000      261500      265200
# 32210         98500       98800       99900      102000      104200
# 33024        226400      229900      234000      237600      240500
# 33009        180300      184100      189000      193600      198500
#
#          2017-01-01  2017-02-01  2017-03-01  2017-04-01  2017-05-01  \
# Zipcode
# 32162        246600      247200      248100      248400      248700
# 33025        269200      272500      275200      277900      279900
# 32210        106600      109500      112000      113600      114900
# 33024        243600      246100      247500      248600      250100
# 33009        204200      209800      214900      219800      223700
#
#          2017-06-01  2017-07-01  2017-08-01  2017-09-01  2017-10-01  \
# Zipcode
# 32162        249300      249900      250400      249900      248700
# 33025        281300      283500      286100      287800      288800
# 32210        115900      116900      118900      121200      122900
# 33024        251600      253400      255400      257500      259800
# 33009        226300      228900      231400      233600      236200
#
#          2017-11-01  2017-12-01  2018-01-01  2018-02-01  2018-03-01  \
# Zipcode
# 32162        247500      247100      246800      247500      249800
# 33025        289700      291000      292500      294200      296400
# 32210        124700      127100      129400      130100      130200
# 33024        261900      263700      265600      267800      269800
# 33009        239000      241000      242600      245100      248100
#
#          2018-04-01
# Zipcode
# 32162        251800
# 33025        298200
# 32210        130400
# 33024        270900
# 33009        250000

# %% [markdown]
# ## Volatility

# %% [markdown]
# ### Explore the Volatility of the Market

# %% [markdown]
# * To filter out the **zipcodes with average risk for investment**, I will **calculate the volatility of prices at each zipcode**. Goal is to extract zipcodes that have averagre volatility, since **low volatility** means **less returns** and **high volatility** might be **too risky.**
#
# !!!!!!!!!!Since **before 2012 the market had a housing bubble** and that fluctuation might affect the volatility results, I will use observations **only after 2012 to investigate the volatility.** !!!!!!!!!!

# %%
#fl_df.columns.get_loc('2012-01-01')

# %%
# fl_df_2012 = fl_df.drop(fl_df.columns[:189], axis=1)
# fl_df_2012.head()

# %%
# fl_df=fl_df.transpose()
# fl_df.head()

# %% [markdown]
# * To calculate Historical Volatility, I will **use standart deviation of log returns**. First, I will need to **calculate historical ROI for each zipcode.**

# %%
def log_roi (df):
    
    hist_df = pd.DataFrame(columns = df.columns)
    
    for col in df.columns:
        hist_df[col] = (np.log(df[col]/df[col].shift(-12)))
    return hist_df

# %%
fl_df_vol = fl_df.transpose()

log_roi_1 = log_roi(fl_df_vol)
log_roi_1.head()
# Out:
# Zipcode        32162     33025     32210     33024     33009     33647  \
# 2012-01-01 -0.054094  0.003727  0.002963 -0.043616  0.076889 -0.015011
# 2012-02-01 -0.055014 -0.004969 -0.004474 -0.050217  0.068092 -0.020460
# 2012-03-01 -0.052854 -0.025975  0.001496 -0.059453  0.043626 -0.028567
# 2012-04-01 -0.050122 -0.049567  0.000000 -0.073347 -0.000918 -0.030730
# 2012-05-01 -0.048814 -0.059891 -0.004501 -0.084741 -0.050598 -0.031506
#
# Zipcode        32244     32822     34711     32218     33064     32174  \
# 2012-01-01  0.005851 -0.062867 -0.094020 -0.023882 -0.075676 -0.046338
# 2012-02-01 -0.009412 -0.082407 -0.079275 -0.041922 -0.081543 -0.050726
# 2012-03-01 -0.012995 -0.095078 -0.067683 -0.047913 -0.100521 -0.050562
# 2012-04-01 -0.008279 -0.103085 -0.064377 -0.047723 -0.126041 -0.056826
# 2012-05-01 -0.011807 -0.111094 -0.065577 -0.071176 -0.144997 -0.064870
#
# Zipcode        33063     34953     33313     32225     32828     33319  \
# 2012-01-01 -0.031772 -0.085506 -0.058472  0.019884 -0.079997 -0.035519
# 2012-02-01 -0.032308 -0.094401 -0.070350  0.006167 -0.091724 -0.041274
# 2012-03-01 -0.039306 -0.106060 -0.090040 -0.010271 -0.104944 -0.040700
# 2012-04-01 -0.057570 -0.113364 -0.118021 -0.027231 -0.114554 -0.048838
# 2012-05-01 -0.076688 -0.123774 -0.137256 -0.042617 -0.119479 -0.077662
#
# Zipcode        33321     32792     32246     32608     33511     32765  \
# 2012-01-01 -0.050097 -0.026765  0.049211  0.018206 -0.025296 -0.064749
# 2012-02-01 -0.068756 -0.048333  0.033638  0.023567 -0.032016 -0.079308
# 2012-03-01 -0.090428 -0.074587  0.014586  0.018998 -0.042738 -0.095718
# 2012-04-01 -0.108830 -0.091586 -0.001708  0.006349 -0.050781 -0.105751
# 2012-05-01 -0.121614 -0.101735 -0.014474 -0.002115 -0.054604 -0.110992
#
# Zipcode        32303     32825     33436     33463     34668     32771  \
# 2012-01-01  0.027302 -0.045894 -0.022701 -0.037059 -0.085418  0.002552
# 2012-02-01  0.032588 -0.057293 -0.034507 -0.033100 -0.084728 -0.007624
# 2012-03-01  0.034289 -0.067862 -0.047924 -0.027270 -0.084049 -0.031082
# 2012-04-01 -0.087809 -0.082912  0.007843 -0.096966 -0.048215 -0.145590
# 2012-05-01 -0.089804 -0.094247 -0.026485 -0.097348 -0.069944 -0.132824
#
# Zipcode        32835     33919     34112     33161     33904     32780  \
# 2012-01-01 -0.047546 -0.067455 -0.015680 -0.050227 -0.091652 -0.023500
# 2012-02-01 -0.070505 -0.062539 -0.014646 -0.074300 -0.090326 -0.038037
# 2012-03-01 -0.103282 -0.063626 -0.020552 -0.086638 -0.094029 -0.036846
# 2012-04-01 -0.131458 -0.074758 -0.031135 -0.093288 -0.099607 -0.032876
# 2012-05-01 -0.149913 -0.087415 -0.042173 -0.104033 -0.104563 -0.031540
#
# Zipcode        33435     32159     34203     34667     32257     34209  \
# 2012-01-01 -0.008563 -0.058589 -0.067555 -0.094751 -0.019595 -0.028113
# 2012-02-01 -0.025689 -0.059034 -0.076430 -0.110901 -0.032148 -0.037458
# 2012-03-01 -0.054658 -0.055479 -0.089501 -0.111496 -0.041078 -0.053994
# 2012-04-01 -0.106880 -0.051260 -0.094899 -0.101487 -0.044882 -0.076342
# 2012-05-01 -0.167846 -0.046460 -0.091000 -0.093023 -0.048690 -0.089095
#
# Zipcode        32566     32073     33177     32907     34609     33844
# 2012-01-01 -0.035304  0.065484 -0.118063 -0.100461  0.006257 -0.067804
# 2012-02-01 -0.037470  0.073340 -0.126692 -0.103649  0.000000 -0.068844
# 2012-03-01 -0.043425  0.073404 -0.126771 -0.099091 -0.011561 -0.082355
# 2012-04-01 -0.051910  0.062979 -0.125019 -0.090749 -0.025238 -0.099342
# 2012-05-01 -0.059833  0.043916 -0.123314 -0.091138 -0.038809 -0.115573

# %%
std_roi_1 = log_roi_1.std()

# %%
std_roi_1 = std_roi_1.to_frame(name = 'std')
std_roi_1.head()
# Out:
#               std
# Zipcode
# 32162    0.039247
# 33025    0.034167
# 32210    0.107179
# 33024    0.034390
# 33009    0.077993

# %%
def annual_std(df):
    
    annual_df = pd.DataFrame(columns = ['annual_std', 'volatility'], index = df.index)
    
    for ind in df.index:
        #print(df['Name'][ind], df['Stream'][ind])
        annual_df.loc[[ind],['annual_std']] = df['std'][ind] * 12 **.5
        annual_df.loc[[ind],['volatility']] = round(df['std'][ind] * 12 **.5, 4)*100
    
    
    return annual_df

# %%
annual_s = annual_std(std_roi_1)
annual_s.head(10)
# Out:
#         annual_std volatility
# Zipcode
# 32162     0.135956       13.6
# 33025     0.118356      11.84
# 32210      0.37128      37.13
# 33024     0.119131      11.91
# 33009     0.270175      27.02
# 33647    0.0705815       7.06
# 32244     0.162018       16.2
# 32822     0.157663      15.77
# 34711    0.0777003       7.77
# 32218     0.121115      12.11

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Median Volatility Rate of Zipcodes')
ax1.boxplot(annual_s['volatility'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc6d543fb70>,
#   <matplotlib.lines.Line2D at 0x7fc6d543f2e8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc6d543f8d0>,
#   <matplotlib.lines.Line2D at 0x7fc6d543fcc0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc6d543f748>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc6d5447198>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc6d5447470>],
#  'means': []}

# %% [markdown]
# * The graph shows that the **median value for volatility rate is around 1.7**. I will **keep zipcodes with volatility rate of 1.7-2.9.** based on project assumptions.

# %%
zipcodes = annual_s.index[(annual_s['volatility'] <13) | (annual_s['volatility'] >24)].to_list()
fl_df.drop(zipcodes, inplace=True)

# %%
len(fl_df)
# Out:
# 43

# %% [markdown]
# ## ROI of 12 Months

# %% [markdown]
# ### Calculate the ROI for the last 12 months

# %% [markdown]
# For the purpose of the project, I will calculate the **average 12 months ROI percentage** of each zipcode, in order to find **zipcodes that have highest return.**

# %%
roi = ((fl_df['2018-04-01'] - fl_df['2017-04-01'])/fl_df['2017-04-01']) * 100
roi.sort_values(ascending=False)
# Out:
# Zipcode
# 32839    23.437500
# 33020    19.830827
# 33313    18.564103
# 33023    17.964946
# 33064    17.718191
# 33615    17.126100
# 33068    16.950053
# 33435    16.413868
# 34667    15.886525
# 33319    14.675592
# 32822    13.793103
# 32907    13.750000
# 33415    13.396005
# 33614    13.337508
# 32073    13.162820
# 32935    12.670300
# 33161    12.282061
# 33617    11.824539
# 33463    11.697575
# 33312    11.334474
# 32703    11.024063
# 34609    10.439921
# 32216    10.386965
# 32244    10.159652
# 32771     9.768908
# 33125     9.059368
# 32246     8.882682
# 32514     8.577878
# 34744     8.565737
# 34741     8.041112
# 33126     7.753336
# 32828     7.429421
# 33063     7.382283
# 32835     6.925323
# 32792     6.658076
# 32303     6.536965
# 32225     5.810259
# 32765     5.658324
# 33436     5.373574
# 34112     4.128114
# 33919     3.469545
# 33914     3.183792
# 32162     1.368760
# dtype: float64

# %%
#roi.plot(style='.', figsize=(20,15))
fig1, ax1 = plt.subplots()
ax1.set_title('One Year ROI for Zipcodes')
ax1.boxplot(roi)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7fc6d5097390>,
#   <matplotlib.lines.Line2D at 0x7fc6d5097668>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fc6d50978d0>,
#   <matplotlib.lines.Line2D at 0x7fc6d5097ba8>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7fc6d5097080>],
#  'medians': [<matplotlib.lines.Line2D at 0x7fc6d5097e80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7fc6d50b4198>],
#  'means': []}

# %% [markdown]
# * The **median ROI** for the last 24 months of all zipcodes in Florida is **11%**, but since the project goal is to find best zipcodes to invest in, I will focus on those zipcodes, that have **return rate higher than upper quantile,** which is 13.5%

# %%
zipcodes = roi.index[roi <13.5].to_list()
fl_df.drop(zipcodes, inplace=True)
fl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, 32822 to 32907
# Data columns (total 76 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   2012-01-01 00:00:00  12 non-null     int64
#  1   2012-02-01 00:00:00  12 non-null     int64
#  2   2012-03-01 00:00:00  12 non-null     int64
#  3   2012-04-01 00:00:00  12 non-null     int64
#  4   2012-05-01 00:00:00  12 non-null     int64
#  5   2012-06-01 00:00:00  12 non-null     int64
#  6   2012-07-01 00:00:00  12 non-null     int64
#  7   2012-08-01 00:00:00  12 non-null     int64
#  8   2012-09-01 00:00:00  12 non-null     int64
#  9   2012-10-01 00:00:00  12 non-null     int64
#  10  2012-11-01 00:00:00  12 non-null     int64
#  11  2012-12-01 00:00:00  12 non-null     int64
#  12  2013-01-01 00:00:00  12 non-null     int64
#  13  2013-02-01 00:00:00  12 non-null     int64
#  14  2013-03-01 00:00:00  12 non-null     int64
#  74  2018-03-01 00:00:00  12 non-null     int64
#  75  2018-04-01 00:00:00  12 non-null     int64
# dtypes: int64(76)
# memory usage: 7.2+ KB

# %%
fl_df = fl_df.transpose()
fl_df.head()
# Out:
# Zipcode     32822  33064  33313   33319  32839  33023   33020  33615  33068  \
# 2012-01-01  78600  86500  93000   96800  68900  98700  101300  97300  90900
# 2012-02-01  78000  87100  93300   97300  69500  97600  102100  96900  90900
# 2012-03-01  78200  87000  93400   98700  70200  96900  102600  96800  91000
# 2012-04-01  79200  87100  93400   99900  70600  97600  103100  96500  91100
# 2012-05-01  80000  87800  93800  100300  71600  98900  103700  96300  91100
#
# Zipcode     33435  34667  32907
# 2012-01-01  81400  97600  75700
# 2012-02-01  80700  97200  76000
# 2012-03-01  80100  97500  76800
# 2012-04-01  78900  98300  77900
# 2012-05-01  77700  99500  78600

# %%
fl_df.plot(figsize=(15,10))
plt.title("Housing Price Trends ")
plt.xlabel('Year')
plt.ylabel('Home Price $')
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.2), ncol= 10, fontsize = 'x-large')
#plt.gcf().autofmt_xdate()

# %% [markdown]
# ### Summary:

# %% [markdown]
# The datast had been cleaned out and filtered down as follows:
# * Zipcodes of **Florida State** had been selected
# * Zipcodes with **urbanization rank** in **top 15 quantile**
# * The **minimum median price of housing is \\$200,000** for the last 4 months
# * The **volatility range** of the median price is **1.7 - 2.9**
# * The **ROI rate is greater than 9.5%**
#
# The initial **amount of zipcodes** was reduced **from 14723 to 14.**

# %% [markdown]
# # Data Preparation

# %% [markdown]
# * Before proceeding to modeling I will check the **data stationarity and autocorrelation of the prices.**

# %% [markdown]
# ## Stationarity of Data

# %%
tsf.stationarity_test(fl_df, 12)

# %%
tsf.dickey_fuller_test(fl_df) # function stored in time_series_funtion file
# Out:
#          test_stats    pvalue usedlag num_of_obs  crit_val_10%
# Zipcode
# 32822      0.996826  0.994232       3         72     -2.588679
# 33064      0.745817  0.990709       4         71     -2.588995
# 33313      1.082558  0.995065       4         71     -2.588995
# 33319      1.252228  0.996328       4         71     -2.588995
# 32839      2.316535  0.998965       4         71     -2.588995
# 33023      2.656804  0.999084       2         73     -2.588371
# 33020      0.620472  0.988110      12         63     -2.591897
# 33615      1.908529  0.998542      11         64     -2.591493
# 33068      1.067597  0.994930       5         70     -2.589320
# 33435      1.519927  0.997596       4         71     -2.588995
# 34667      1.917238  0.998555       7         68     -2.590001
# 32907      1.551004  0.997703      10         65     -2.591103

# %% [markdown]
# * As the **Dickey- Fuller Test** shows, none of the **zipcodes'** data **do not meet stationarity assumption**. I will build the autocorrelation and partial autocorrelation graphs, and try **auto-arima model as a baseline** to retrieve optimal p,d,q parameters.

# %% [markdown]
# # Baseline Model

# %% [markdown]
# ## Train Test Split

# %% [markdown]
# * To proceed with modeling, I will create **12 separate datasets** with **time as index and median price as value** and **transform** them in accordance with previous observations.

# %%
fl_df.plot(figsize=(15,10))
plt.title("Housing Price Trends")
plt.xlabel('Year')
plt.ylabel('Home Price $')
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.2), ncol= 10, fontsize = 'x-large')

# %%
df_33064 = pd.DataFrame(fl_df['33064'])
df_33064.index.name = 'time'
df_33313 = pd.DataFrame(fl_df['33313'])
df_33313.index.name = 'time'
df_33319 = pd.DataFrame(fl_df['33319'])   
df_33319.index.name = 'time'
df_33068 = pd.DataFrame(fl_df['33068'])
df_33068.index.name = 'time'
df_33435 = pd.DataFrame(fl_df['33435'])
df_33435.index.name = 'time'
df_32839 = pd.DataFrame(fl_df['32839'])
df_32839.index.name = 'time'
df_32822 = pd.DataFrame(fl_df['32822'])
df_32822.index.name = 'time'
df_33023 = pd.DataFrame(fl_df['33023'])
df_33023.index.name = 'time'
df_33020 = pd.DataFrame(fl_df['33020'])
df_33020.index.name = 'time'
df_33615 = pd.DataFrame(fl_df['33615'])
df_33615.index.name = 'time'
df_34667 = pd.DataFrame(fl_df['34667'])
df_34667.index.name = 'time'
df_32907 = pd.DataFrame(fl_df['32907'])
df_32907.index.name = 'time'

# %% [markdown]
# * The holdout set will be 20% of the data, the test set will consist of 20% of 80% that was left for trainig.

# %%
train_1,test_1,hold_1 = ed.train_test_holdout_split(df_33064)
train_2,test_2,hold_2 = ed.train_test_holdout_split(df_33313.dropna())
train_3,test_3,hold_3 = ed.train_test_holdout_split(df_33319.dropna())
train_4,test_4,hold_4 = ed.train_test_holdout_split(df_33068.dropna())
train_5,test_5,hold_5 = ed.train_test_holdout_split(df_33435.dropna())
train_6,test_6,hold_6 = ed.train_test_holdout_split(df_32839.dropna())

train_7,test_7,hold_7 = ed.train_test_holdout_split(df_32822.dropna())
train_8,test_8,hold_8 = ed.train_test_holdout_split(df_33023.dropna())
train_9,test_9,hold_9 = ed.train_test_holdout_split(df_33020.dropna())
train_10,test_10,hold_10 = ed.train_test_holdout_split(df_33615.dropna())
train_11,test_11,hold_11 = ed.train_test_holdout_split(df_34667.dropna())
train_12,test_12,hold_12 = ed.train_test_holdout_split(df_32907.dropna())

# %% [markdown]
# # Auto - ARIMA for all Zipcodes

# %% [markdown]
# * Auto-ARIMA Model grid searches the most optimal parameters for the best

# %%
# create dataframe to store models' parameters
metrics = pd.DataFrame(columns = ['Order', 'AIC', 'Testing RMSE'], index = fl_df.columns)

# %% [markdown]
# ## 33064 Zipcode Model

# %%
model_1 = auto_arima(train_1, stationary = False, start_p = 1, start_q = 0, seasonal = False)

forecast_1 = tsf.evaluate_auto_arima(model_1, train_1, test_1, metrics)
model_1.summary()
# Out:
# Testing RMSE =  6730.051070604531
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   48
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                -375.897
# Date:                Wed, 15 Sep 2021   AIC                            759.793
# Time:                        19:34:55   BIC                            767.194
# Sample:                             0   HQIC                           762.578
#                                  - 48
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    199.4284    171.919      1.160      0.246    -137.527     536.384
# ar.L1          0.8638      0.130      6.660      0.000       0.610       1.118
# ma.L1         -0.9112      0.119     -7.659      0.000      -1.144      -0.678
# sigma2      5.419e+05   1.31e+05      4.124      0.000    2.84e+05    7.99e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                  33.87   Jarque-Bera (JB):                 0.11
# Prob(Q):                              0.00   Prob(JB):                         0.95
# Heteroskedasticity (H):               1.86   Skew:                            -0.11
# Prob(H) (two-sided):                  0.23   Kurtosis:                         2.91
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ## 33313 Zipcode Model

# %%
model_2 = auto_arima(train_2, stationary = False, start_p = 1, start_q = 0, seasonal = False)

forecast_2 = tsf.evaluate_auto_arima(model_2, train_2, test_2, metrics)
model_2.summary()
# Out:
# Testing RMSE =  5668.685829907671
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   48
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                -380.068
# Date:                Wed, 15 Sep 2021   AIC                            768.137
# Time:                        19:34:56   BIC                            775.538
# Sample:                             0   HQIC                           770.922
#                                  - 48
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    379.1489    316.029      1.200      0.230    -240.257     998.555
# ar.L1          0.7298      0.235      3.100      0.002       0.268       1.191
# ma.L1         -0.7738      0.220     -3.511      0.000      -1.206      -0.342
# sigma2      6.632e+05   1.55e+05      4.269      0.000    3.59e+05    9.68e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                  30.70   Jarque-Bera (JB):                 0.09
# Prob(Q):                              0.00   Prob(JB):                         0.96
# Heteroskedasticity (H):               1.15   Skew:                             0.06
# Prob(H) (two-sided):                  0.78   Kurtosis:                         2.83
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ## 33319 Zipcode Model

# %%
model_3 = auto_arima(train_3, stationary = False, start_p = 1, start_q = 0, seasonal = False)

forecast_3 = tsf.evaluate_auto_arima(model_3, train_3, test_3, metrics)
model_3.summary()
# Out:
# Testing RMSE =  7994.047459137058
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   48
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                -390.315
# Date:                Wed, 15 Sep 2021   AIC                            784.629
# Time:                        19:34:56   BIC                            788.330
# Sample:                             0   HQIC                           786.022
#                                  - 48
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   1234.0426    150.331      8.209      0.000     939.400    1528.685
# sigma2      9.567e+05   1.97e+05      4.866      0.000    5.71e+05    1.34e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                  36.55   Jarque-Bera (JB):                 1.85
# Prob(Q):                              0.00   Prob(JB):                         0.40
# Heteroskedasticity (H):               0.30   Skew:                             0.47
# Prob(H) (two-sided):                  0.02   Kurtosis:                         3.24
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ## 33068 Zipcode Model

# %%
model_4 = auto_arima(train_4, stationary = False, start_p = 1, start_q = 0, seasonal = False)

forecast_4 = tsf.evaluate_auto_arima(model_4, train_4, test_4, metrics)
model_4.summary()
# Out:
# Testing RMSE =  8178.503491962778
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   48
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                -374.214
# Date:                Wed, 15 Sep 2021   AIC                            756.428
# Time:                        19:34:57   BIC                            763.829
# Sample:                             0   HQIC                           759.213
#                                  - 48
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    171.8836    108.688      1.581      0.114     -41.140     384.907
# ar.L1          0.8856      0.084     10.510      0.000       0.720       1.051
# ma.L1         -0.9889      0.220     -4.500      0.000      -1.420      -0.558
# sigma2      5.265e+05      0.036   1.45e+07      0.000    5.27e+05    5.27e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                  36.98   Jarque-Bera (JB):                 1.20
# Prob(Q):                              0.00   Prob(JB):                         0.55
# Heteroskedasticity (H):               0.63   Skew:                             0.28
# Prob(H) (two-sided):                  0.37   Kurtosis:                         2.44
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 6.58e+22. Standard errors may be unstable.
# """

# %% [markdown]
# ## 33435 Zipcode Model

# %%
model_5 = auto_arima(train_5, stationary = False, start_p = 1, start_q = 0, seasonal = False)

forecast_5 = tsf.evaluate_auto_arima(model_5, train_5, test_5, metrics)
model_5.summary()
# Out:
# Testing RMSE =  1286.1441080480315
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   48
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                -362.546
# Date:                Wed, 15 Sep 2021   AIC                            727.091
# Time:                        19:34:57   BIC                            728.920
# Sample:                             0   HQIC                           727.776
#                                  - 48
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      4.099e+05   1.01e+05      4.039      0.000    2.11e+05    6.09e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   9.36   Jarque-Bera (JB):                 0.86
# Prob(Q):                              0.00   Prob(JB):                         0.65
# Heteroskedasticity (H):               0.50   Skew:                             0.11
# Prob(H) (two-sided):                  0.19   Kurtosis:                         2.37
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ## 32839 Zipcode Model

# %%
model_6 = auto_arima(train_6, stationary = False, start_p = 1, start_q = 0, seasonal = False)

forecast_6 = tsf.evaluate_auto_arima(model_6, train_6, test_6, metrics)
model_6.summary()
# Out:
# Testing RMSE =  1731.9392892142882
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   48
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                -380.562
# Date:                Wed, 15 Sep 2021   AIC                            765.125
# Time:                        19:34:57   BIC                            768.825
# Sample:                             0   HQIC                           766.517
#                                  - 48
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   1019.1489    116.007      8.785      0.000     791.780    1246.518
# sigma2      6.318e+05   1.64e+05      3.854      0.000     3.1e+05    9.53e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                  29.85   Jarque-Bera (JB):                 1.07
# Prob(Q):                              0.00   Prob(JB):                         0.59
# Heteroskedasticity (H):               0.62   Skew:                            -0.04
# Prob(H) (two-sided):                  0.35   Kurtosis:                         2.27
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ## 32822 Zipcode Model

# %%
model_7 = auto_arima(train_7, stationary = False, start_p = 1, start_q = 0, seasonal = False)

forecast_7 = tsf.evaluate_auto_arima(model_7, train_7, test_7, metrics)
model_7.summary()
# Out:
# Testing RMSE =  2901.9945593377156
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   48
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                -373.532
# Date:                Wed, 15 Sep 2021   AIC                            755.063
# Time:                        19:34:58   BIC                            762.464
# Sample:                             0   HQIC                           757.848
#                                  - 48
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    151.8326    111.845      1.358      0.175     -67.379     371.044
# ar.L1          0.9003      0.088     10.177      0.000       0.727       1.074
# ma.L1         -0.9732      0.158     -6.163      0.000      -1.283      -0.664
# sigma2      5.137e+05      0.010   5.06e+07      0.000    5.14e+05    5.14e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                  31.98   Jarque-Bera (JB):                 5.04
# Prob(Q):                              0.00   Prob(JB):                         0.08
# Heteroskedasticity (H):               1.04   Skew:                             0.80
# Prob(H) (two-sided):                  0.93   Kurtosis:                         2.98
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.99e+25. Standard errors may be unstable.
# """

# %% [markdown]
# ## 33023 Zipcode Model

# %%
model_8 = auto_arima(train_8,stationary = False, start_p = 1, start_q = 0, seasonal = False)

forecast_8 = tsf.evaluate_auto_arima(model_8, train_8, test_8, metrics)
model_8.summary()
# Out:
# Testing RMSE =  11972.936026087204
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   48
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                -366.263
# Date:                Wed, 15 Sep 2021   AIC                            740.526
# Time:                        19:34:59   BIC                            747.927
# Sample:                             0   HQIC                           743.311
#                                  - 48
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    471.4987    260.875      1.807      0.071     -39.808     982.805
# ar.L1          0.6383      0.211      3.030      0.002       0.225       1.051
# ma.L1         -0.7338      0.195     -3.764      0.000      -1.116      -0.352
# sigma2       3.83e+05   1.13e+05      3.393      0.001    1.62e+05    6.04e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                  23.36   Jarque-Bera (JB):                 0.37
# Prob(Q):                              0.00   Prob(JB):                         0.83
# Heteroskedasticity (H):               0.45   Skew:                            -0.15
# Prob(H) (two-sided):                  0.12   Kurtosis:                         2.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model_9 = auto_arima(train_9,stationary = False, start_p = 1, start_q = 0, seasonal = False)

forecast_9 = tsf.evaluate_auto_arima(model_9, train_9, test_9, metrics)
model_9.summary()
# Out:
# Testing RMSE =  11450.852326928763
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   48
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                -391.826
# Date:                Wed, 15 Sep 2021   AIC                            787.652
# Time:                        19:34:59   BIC                            791.352
# Sample:                             0   HQIC                           789.044
#                                  - 48
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   1312.7660    202.900      6.470      0.000     915.090    1710.442
# sigma2       1.02e+06   2.33e+05      4.386      0.000    5.64e+05    1.48e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                  29.42   Jarque-Bera (JB):                13.89
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.58   Skew:                             1.21
# Prob(H) (two-sided):                  0.29   Kurtosis:                         4.10
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model_10 = auto_arima(train_10,stationary = False, start_p = 1, start_q = 0, seasonal = False)

forecast_10 = tsf.evaluate_auto_arima(model_10, train_10, test_10, metrics)
model_10.summary()
# Out:
# Testing RMSE =  10423.106033533313
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   48
# Model:               SARIMAX(1, 1, 1)   Log Likelihood                -378.567
# Date:                Wed, 15 Sep 2021   AIC                            765.134
# Time:                        19:35:00   BIC                            772.534
# Sample:                             0   HQIC                           767.919
#                                  - 48
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    113.6767    148.933      0.763      0.445    -178.226     405.579
# ar.L1          0.9000      0.156      5.783      0.000       0.595       1.205
# ma.L1         -0.9536      0.135     -7.068      0.000      -1.218      -0.689
# sigma2      6.674e+05   1.79e+05      3.735      0.000    3.17e+05    1.02e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                  28.74   Jarque-Bera (JB):                 0.16
# Prob(Q):                              0.00   Prob(JB):                         0.92
# Heteroskedasticity (H):               1.92   Skew:                             0.07
# Prob(H) (two-sided):                  0.20   Kurtosis:                         2.75
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model_11 = auto_arima(train_11,stationary = False, start_p = 1, start_q = 0, seasonal = False)

forecast_11 = tsf.evaluate_auto_arima(model_11, train_11, test_11, metrics)
model_11.summary()
# Out:
# Testing RMSE =  2529.087759474913
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   48
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                -369.631
# Date:                Wed, 15 Sep 2021   AIC                            743.262
# Time:                        19:35:01   BIC                            746.963
# Sample:                             0   HQIC                           744.655
#                                  - 48
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    593.6170     92.409      6.424      0.000     412.499     774.735
# sigma2      3.968e+05   1.26e+05      3.160      0.002    1.51e+05    6.43e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                  25.75   Jarque-Bera (JB):                 2.62
# Prob(Q):                              0.00   Prob(JB):                         0.27
# Heteroskedasticity (H):               1.52   Skew:                            -0.10
# Prob(H) (two-sided):                  0.41   Kurtosis:                         1.86
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model_12 = auto_arima(train_12,stationary = False, start_p = 1, start_q = 0, seasonal = False)

forecast_12 = tsf.evaluate_auto_arima(model_12, train_12, test_12, metrics)
model_12.summary()
# Out:
# Testing RMSE =  2305.7898140695015
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   48
# Model:               SARIMAX(0, 2, 0)   Log Likelihood                -341.947
# Date:                Wed, 15 Sep 2021   AIC                            685.894
# Time:                        19:35:01   BIC                            687.723
# Sample:                             0   HQIC                           686.579
#                                  - 48
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      1.673e+05   3.46e+04      4.831      0.000    9.94e+04    2.35e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   3.87   Jarque-Bera (JB):                 0.12
# Prob(Q):                              0.05   Prob(JB):                         0.94
# Heteroskedasticity (H):               0.92   Skew:                             0.13
# Prob(H) (two-sided):                  0.87   Kurtosis:                         2.99
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
metrics
# Out:
#              Order     AIC Testing RMSE
# Zipcode
# 32822    [1, 1, 1]  755.06      2901.99
# 33064    [1, 1, 1]  759.79      6730.05
# 33313    [1, 1, 1]  768.14      5668.69
# 33319    [0, 1, 0]  784.63      7994.05
# 32839    [0, 1, 0]  765.12      1731.94
# 33023    [1, 1, 1]  740.53      11972.9
# 33020    [0, 1, 0]  787.65      11450.9
# 33615    [1, 1, 1]  765.13      10423.1
# 33068    [1, 1, 1]  756.43       8178.5
# 33435    [0, 2, 0]  727.09      1286.14
# 34667    [0, 1, 0]  743.26      2529.09
# 32907    [0, 2, 0]  685.89      2305.79

# %% [markdown]
# *  In order to choose **5 out of 12 Zipcodes**, I will calculate the **percentage of the predicted ROI** and filter out zipcodes with low values. I will calculate the change between beginning of the forecast and the end.

# %%
def forecast_roi(forecasts, dfs, roi_df):
    
    for i, zipcode in enumerate(roi_df.index):
        roi_df.loc[[zipcode],['forecast_roi']] = ((forecasts[i]['Prediction'][-1] - 
                                                   forecasts[i]['Prediction'][0])/forecasts[i]['Prediction'][0])*100
        roi_df.loc[[zipcode],['actual_roi']] = ((dfs[i][list(dfs[i].columns)[0]][-1] - dfs[i][list(dfs[i].columns)[0]][0])/dfs[i][list(dfs[i].columns)[0]][0])*100
        
    return roi_df

# %%
forecasts = [forecast_1,forecast_2,forecast_3,forecast_4,forecast_5,forecast_6,
             forecast_7,forecast_8,forecast_9,forecast_10,forecast_11,forecast_12]
tests = [test_1, test_2, test_3, test_4, test_5, test_6, test_7, test_8, test_9, test_10, test_11, test_12]

# %%
forecast_roi1 = pd.DataFrame(columns = ['forecast_roi', 'actual_roi'], index = fl_df.columns)

# %%
forecast_roi(forecasts, tests, forecast_roi1)
# Out:
#         forecast_roi actual_roi
# Zipcode
# 32822        10.7155    18.6452
# 33064        10.3127    19.5924
# 33313        8.69968    18.5897
# 33319        11.7726    22.6712
# 32839        13.6334     14.769
# 33023        9.51512     13.896
# 33020        12.8842    17.7502
# 33615        9.35171    24.9025
# 33068        8.78838    20.2654
# 33435        9.48096    20.6871
# 34667        5.17852    8.71632
# 32907        13.5698    11.9323

# %% [markdown]
# ### Results:
#
# To proceed further with modeling, I will **drop zipcodes that had lowest ROI** compared to actual ROI. Those are **33313, 33319, 33615, 33068, 33435**. And I will try different models on those zipcodes that had average results: **32822, 33064**

# %% [markdown]
# ### Summary:

# %% [markdown]
# * Standardized residual graphs show that the **residual errors fluctuate around 150** for both of the models.
# * Histogram of the **Model 1** shows **normally distributed residuals**, since KDE and N are close to each other.
# * The **Normal Q-Q** graph shows **better performance of Model 1.**
# * **Correlogram** shows **non significant correlation** for both models.

# %% [markdown]
# # Facebook Prophet Model

# %% [markdown]
# I will build a Facebook Prophet Model since it suppose to performe better with seasonal data, be robust to shifts in trend and hande outliers well.

# %% [markdown]
# ### Train - Test Split

# %% [markdown]
# The data for FB Prophet should be non differenced, thus I will create new train and test splits for modeling.

# %%
# the function returns the datasets with resetted index and column names ds and y, 
# since that's a FB Prophet convention
ed.prophet_df([train_1, test_1])
ed.prophet_df([train_6, test_6])
ed.prophet_df([train_7, test_7])
ed.prophet_df([train_8, test_8])
ed.prophet_df([train_9, test_9])
ed.prophet_df([train_11, test_11])
ed.prophet_df([train_12, test_12])

# %% [markdown]
# ### 33064 Zipcode

# %%
pmodel_1 = Prophet()
pmodel_1.fit(train_1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-139-53f1b1da9b11> in <module>
#       1 pmodel_1 = Prophet()
# ----> 2 pmodel_1.fit(train_1)
#
# /opt/anaconda3/envs/topzipcode/lib/python3.6/site-packages/fbprophet/forecaster.py in fit(self, df, **kwargs)
#    1024         history = self.setup_dataframe(history, initialize_scales=True)
#    1025         self.history = history
# -> 1026         self.set_auto_seasonalities()
#    1027         seasonal_features, prior_scales, component_cols, modes = (
#    1028             self.make_all_seasonality_features(history))
#
# /opt/anaconda3/envs/topzipcode/lib/python3.6/site-packages/fbprophet/forecaster.py in set_auto_seasonalities(self)
#     878         last = self.history['ds'].max()
#     879         dt = self.history['ds'].diff()
# --> 880         min_dt = dt.iloc[dt.nonzero()[0]].min()
#     881
#     882         # Yearly seasonality
#
# /opt/anaconda3/envs/topzipcode/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5139             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5140                 return self[name]
# -> 5141             return object.__getattribute__(self, name)
#    5142
#    5143     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'nonzero'

# %%
pdf_1 = pmodel_1.make_future_dataframe(periods=len(ptest_1), freq='MS')

# %%
forecast_1 = pmodel_1.predict(pdf_1)
forecast_1.head()

# %%
pmodel_1.plot(forecast_1, uncertainty=True)
plt.show()

# %%
pmodel_1.plot_components(forecast_1)
plt.show()

# %% [markdown]
# * Now I will plot forecast values with actual values and calculate the RMSE

# %%
y_pred = forecast_1['yhat'][-22:].values

testing_MSE = mean_squared_error(ptest_1, y_pred)**.5
print('Testing RMSE = ', testing_MSE)

#mae_1 = mean_absolute_error(y_true, y_pred)
#print('MAE: %.3f' % mae)

# plot expected vs actual
plt.plot(ptest_1.values, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.show()

# %% [markdown]
# ### 33033 Zipcode

# %%
pmodel_7 = Prophet(weekly_seasonality=True, daily_seasonality=True)
pmodel_7.fit(ptrain_7)

# %%
pdf_7 = pmodel_7.make_future_dataframe(periods=len(ptest_7), freq='MS')

# %%
forecast_7 = pmodel_7.predict(pdf_7)
forecast_7.head()

# %%
pmodel_7.plot(forecast_7, uncertainty=True)
plt.show()

# %%
pmodel_7.plot_components(forecast_7)
plt.show()

# %% [markdown]
# * Now I will plot forecast values with actual values and calculate the RMSE

# %%
y_pred = forecast_7['yhat'][-22:].values

testing_MSE = mean_squared_error(ptest_7, y_pred)**.5
print('Testing RMSE = ', testing_MSE)

#mae_1 = mean_absolute_error(y_true, y_pred)
#print('MAE: %.3f' % mae)

# plot expected vs actual
plt.plot(ptest_7.values, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.show()

# %% [markdown]
# ### 33157 Zipcode

# %%
pmodel_2 = Prophet(weekly_seasonality=True, daily_seasonality=True)
pmodel_2.fit(ptrain_2)

# %%
pdf_2 = pmodel_2.make_future_dataframe(periods=len(ptest_2), freq='MS')

# %%
forecast_2 = pmodel_2.predict(pdf_2)
forecast_2.head()

# %%
pmodel_2.plot(forecast_2, uncertainty=True)
plt.show()

# %%
pmodel_2.plot_components(forecast_2)
plt.show()

# %% [markdown]
# * Now I will plot forecast values with actual values and calculate the RMSE

# %%
y_pred = forecast_2['yhat'][-22:].values

testing_MSE = mean_squared_error(ptest_2, y_pred)**.5
print('Testing RMSE = ', testing_MSE)

#mae_1 = mean_absolute_error(y_true, y_pred)
#print('MAE: %.3f' % mae)

# plot expected vs actual
plt.plot(ptest_2.values, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.legend()
plt.show()

# %% [markdown]
# ### Summary:

# %% [markdown]
# After building models for three datasets, it is clear that **Facebook Prophet performed worse than ARIMA models**. The **Mean Squared Error is higher with Prophet** and due to noticable fluctuation in dataset, the model **forecasts in downward direction**, whereas the **actual values go up**.

# %% [markdown]
# ## Final Model SARIMAX (2, 0, 0) with Holdout Data

# %% [markdown]
# The evaluation of all models showed that **SARIMAX model built by auto-ARIMA** for zipcode "33064" **performed better** than others. Thus, I will build SARIMAX model with test and holdout data.

# %%
# metrics dataframe to store metrics of all zipcodes

metrics_hold = pd.DataFrame(columns = ['AIC', 'Training RMSE','Testing RMSE'], index = df_final.columns)

# holdout dataframes

holdout_df = [hold_1, hold_2, hold_3, hold_4, hold_5, hold_6, hold_7, hold_8]

# %%
#call SARIMAX function 
f_ct1, f_ct2, f_ct3, f_ct4, f_ct5, f_ct6, f_ct7, f_ct8 = tsf.sarimax_final_model(train_df, 
                                                                                 test_df, holdout_df, 
                                                                                 metrics_hold)

# %%
metrics_hold

# %% [markdown]
# # Results and Conclusion

# %% [markdown]
# Based on model metrics, the following zipcodes are the best options: **33064, 32825, 32771, 33033, 34698**. Now, I will calculate the actual values of the forecast and print out last metrics.

# %%
#forecast_df = [f_ct1, f_ct3, f_ct4, f_ct6, f_ct8]

# %%
# f_df1 = pd.DataFrame(fl_df['33064'])
# f_df2 = pd.DataFrame(fl_df['32825'])
# f_df3 = pd.DataFrame(fl_df['34698'])
# f_df4 = pd.DataFrame(fl_df['33033'])
# f_df5 = pd.DataFrame(fl_df['32771'])

# final_df = [f_df1, f_df2, f_df3, f_df4, f_df5]

# for df in final_df:
#     df.reset_index(drop=True, inplace=True)

# %%
# def calc_median(df):
#     return df.median()
    
# def calc_forecast_ROI(forecast):
    
#     return ((np.exp(forecast.iloc[-1]) - np.exp(forecast.iloc[-2]))/
#             np.exp(forecast.iloc[-1]))

# def final_ROI(dfs, forecasts, roi):
#     comparison = pd.DataFrame(columns=['Median_Housing_Price','Actual_2018_ROI', 'Forecast_2018_ROI'], 
#                               index = ['33064', '32825', '34698', '33033', '32771'])
    
# #     for i in range(len(comparison.columns)):
# #         comparison[[0][i]] = dfs[i][:,0].median(axis = 0)
# #         comparison[[1][i]] = round(roi[i], 3)
# #         comparison[[2][i]] = round(100*calc_forecast_ROI(forecasts[i]),2)
        
#     for i in range(len(dfs)):
#         comparison['Median_Housing_Price'].loc[list(dfs[i].columns)[0]] = list(dfs[i].median())[0]
#         comparison['Actual_2018_ROI'].loc[list(dfs[i].columns)[0]] = round(roi[list(dfs[i].columns)[0]], 3)
#         comparison['Forecast_2018_ROI'].loc[list(dfs[i].columns)[0]] = round(100*calc_forecast_ROI(forecasts[i]),2)
        
    
    
    
# #     for i, df in enumerate(dfs):
# #         metrics = [df.iloc[0,-1], round(roi.loc[list(df.columns)[1]]), 
# #                    round(100*calc_forecast_ROI(forecasts[i]),2)]
# #         comparison[df[[list(df.columns)[0][0]]] = metrics        
#     return comparison

# %%
# final_metric = final_ROI(final_df, forecast_df, roi)
# final_metric

# %% [markdown]
# ### Results:
#
# * All **training data overfitted models**.
# * The **models are all very skewed** because of the market crash in 2009.
# * Relying on the project assumptions, data exploration and modeling, following zipcodes are chosen as best ones to invest in:**33064, 32825, 32771, 33033, 34698**
#
# ### Notes:
#
# * Real estate **predictions** may vary due to **unseen fluctuations** in the market.
#
# ### Next Steps:
#
# * Obtain **data after 2018 for current predictions.
# * Use **samples only after Great Recession** period to model.
# * Set **ROI threshold to lower values.**

# %%
calc_forecast_ROI(f_ct3)

# %%
list(f_ct1[0]).predicted_mean()

# %%
list(final_df[0].median())[0]

# %%
roi['33064']

# %%
list(final_df[0].columns)[0]

# %%
type(roi)

# %%
list(f_df1.columns)[0]
